# %%
import sys
# !{sys.executable} -m pip install selenium webdriver-manager requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting selenium
#   Downloading selenium-4.44.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: requests in C:\ProgramData\anaconda3\Lib\site-packages (2.32.3)
# Collecting certifi>=2026.2.25 (from selenium)
#   Downloading certifi-2026.5.20-py3-none-any.whl.metadata (2.5 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting typing_extensions<5.0,>=4.15.0 (from selenium)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting urllib3<3.0,>=2.6.3 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in C:\ProgramData\anaconda3\Lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.7)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in C:\ProgramData\anaconda3\Lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: python-dotenv in C:\ProgramData\anaconda3\Lib\site-packages (from webdriver-manager) (1.1.0)
# Requirement already satisfied: packaging in C:\ProgramData\anaconda3\Lib\site-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\ProgramData\anaconda3\Lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: pycparser in C:\ProgramData\anaconda3\Lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.16.0 in C:\ProgramData\anaconda3\Lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.44.0-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.7 MB 2.9 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.7 MB 4.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/9.7 MB 4.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.7 MB 4.3 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.7 MB 4.8 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.7 MB 5.2 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.7 MB 5.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.7 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 4.9 MB/s  0:00:02
# Downloading trio-0.33.0-py3-none-any.whl (510 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading webdriver_manager-4.1.1-py3-none-any.whl (32 kB)
# Downloading certifi-2026.5.20-py3-none-any.whl (134 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, typing_extensions, outcome, certifi, trio, webdriver-manager, trio-websocket, selenium
#
#    ---------------------------------------- 0/9 [wsproto]
#    ---- ----------------------------------- 1/9 [urllib3]
#    ---- ----------------------------------- 1/9 [urllib3]
#    ---- ----------------------------------- 1/9 [urllib3]
#    ---- ----------------------------------- 1/9 [urllib3]
#    ---- ----------------------------------- 1/9 [urllib3]
#    ---- ----------------------------------- 1/9 [urllib3]
#    ---- ----------------------------------- 1/9 [urllib3]
#    ---- ----------------------------------- 1/9 [urllib3]
#    ---- ----------------------------------- 1/9 [urllib3]
#    -------- ------------------------------- 2/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [outcome]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    -------------------------- ------------- 6/9 [webdriver-manager]
#    -------------------------- ------------- 6/9 [webdriver-manager]
#    -------------------------- ------------- 6/9 [webdriver-manager]
#    -------------------------- ------------- 6/9 [webdriver-manager]
#    ------------------------------- -------- 7/9 [trio-websocket]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ----------------------------------- ---- 8/9 [selenium]
#    ---------------------------------------- 9/9 [selenium]
#
# Successfully installed certifi-2026.5.20 outcome-1.3.0.post0 selenium-4.44.0 trio-0.33.0 trio-websocket-0.12.2 typing_extensions-4.15.0 urllib3-2.7.0 webdriver-manager-4.1.1 wsproto-1.3.2

# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install selenium webdriver-manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in C:\Users\Pranav\AppData\Roaming\Python\Python313\site-packages (4.44.0)
# Requirement already satisfied: webdriver-manager in C:\Users\Pranav\AppData\Roaming\Python\Python313\site-packages (4.1.1)
# Requirement already satisfied: certifi>=2026.2.25 in C:\Users\Pranav\AppData\Roaming\Python\Python313\site-packages (from selenium) (2026.5.20)
# Requirement already satisfied: trio<1.0,>=0.31.0 in C:\Users\Pranav\AppData\Roaming\Python\Python313\site-packages (from selenium) (0.33.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in C:\Users\Pranav\AppData\Roaming\Python\Python313\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in C:\Users\Pranav\AppData\Roaming\Python\Python313\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in C:\Users\Pranav\AppData\Roaming\Python\Python313\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.7.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in C:\ProgramData\anaconda3\Lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.7)
# Requirement already satisfied: outcome in C:\Users\Pranav\AppData\Roaming\Python\Python313\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in C:\ProgramData\anaconda3\Lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in C:\Users\Pranav\AppData\Roaming\Python\Python313\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in C:\ProgramData\anaconda3\Lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: requests in C:\ProgramData\anaconda3\Lib\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in C:\ProgramData\anaconda3\Lib\site-packages (from webdriver-manager) (1.1.0)
# Requirement already satisfied: packaging in C:\ProgramData\anaconda3\Lib\site-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: pycparser in C:\ProgramData\anaconda3\Lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.16.0 in C:\ProgramData\anaconda3\Lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\ProgramData\anaconda3\Lib\site-packages (from requests->webdriver-manager) (3.3.2)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import requests
import os

# %%
query = "Virat kohli"
num_image = 20
save_folder = "image"
os.makedirs(save_folder, exist_ok = True)

# %%
#------Chrome Setup
services = Service(ChromeDriverManager().install())
options = webdriver.ChromeOptions()
options.add_argument("--incognito")
driver = webdriver.Chrome(service = services,options = options)

#------Open google Image
driver.get("https://images.google.com/")

#------Search
search_box = driver.find_element(By.NAME,"q")
search_box.send_keys(query)
search_box.send_keys(Keys.RETURN)

time.sleep(5)

#--------Scroll

for _ in range(6):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
#----------Download image

images = driver.find_elements(By.CSS_SELECTOR,"img[src^='http']")

count = 0
for img in images:
    try:
        src = img.get_attribute("src")

        if src and src.startswith("http"):
            response = requests.get(src , timeout = 5)

            if response.status_code == 200:
                file_path = os.path.join(save_folder,f"{query}_{count}.jpg")


                with open(file_path,"wb") as f:
                    f.write(response.content)


            count += 1
            print(f"Downloded {count}")

        if count >= num_images:
            break


    except Exception as e:
        pass

driver.quit()
print("Done")
# Out:
# Downloded 1
# Downloded 2
# Downloded 3
# Downloded 4
# Downloded 5
# Downloded 6
# Downloded 7
# Downloded 8
# Downloded 9
# Downloded 10
# Downloded 11
# Downloded 12
# Downloded 13
# Downloded 14
# Downloded 15
# Downloded 16
# Downloded 17
# Downloded 18
# Downloded 19
# Downloded 20
# Downloded 21
# Downloded 22
# Downloded 23
# Downloded 24
# Downloded 25
# Downloded 26
# Downloded 27
# Downloded 28
# Downloded 29
# Downloded 30
# Downloded 31
# Downloded 32
# Downloded 33
# Downloded 34
# Downloded 35
# Downloded 36
# Downloded 37
# Downloded 38
# Downloded 39
# Downloded 40
# Downloded 41
# Downloded 42
# Downloded 43
# Downloded 44
# Downloded 45
# Downloded 46
# Downloded 47
# Downloded 48
# Downloded 49
# Downloded 50
# Downloded 51
# Downloded 52
# Downloded 53
# Downloded 54
# Downloded 55
# Downloded 56
# Downloded 57
# Downloded 58
# Downloded 59
# Downloded 60
# Downloded 61
# Downloded 62
# Downloded 63
# Downloded 64
# Downloded 65
# Downloded 66
# Downloded 67
# Downloded 68
# Downloded 69
# Downloded 70
# Downloded 71
# Downloded 72
# Downloded 73
# Downloded 74
# Downloded 75
# Downloded 76
# Downloded 77
# Downloded 78
# Downloded 79
# Downloded 80
# Downloded 81
# Downloded 82
# Downloded 83
# Downloded 84
# Downloded 85
# Downloded 86
# Downloded 87
# Downloded 88
# Downloded 89
# Downloded 90
# Downloded 91
# Downloded 92
# Downloded 93
# Downloded 94
# Downloded 95
# Downloded 96
# Downloded 97
# Downloded 98
# Downloded 99
# Downloded 100
# Downloded 101
# Downloded 102
# Downloded 103
# Downloded 104
# Downloded 105
# Downloded 106
# Downloded 107
# Downloded 108
# Downloded 109
# Downloded 110
# Downloded 111
# Downloded 112
# Downloded 113
# Downloded 114
# Downloded 115
# Downloded 116
# Downloded 117
# Downloded 118
# Downloded 119
# Downloded 120
# Downloded 121
# Downloded 122
# Downloded 123
# Downloded 124
# Downloded 125
# Downloded 126
# Done
